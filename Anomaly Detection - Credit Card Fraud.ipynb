# %% [markdown]
# Starting with importing the packages

# %%
import numpy as np
import pandas as pd
import sklearn
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, accuracy_score
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import OneClassSVM
from pylab import rcParams
rcParams['figure.figsize'] = 20,14
RANDOM_SEED = 42
LABELS = ["Normal","Fraud"]

# %% [markdown]
# Lets read the data and have a glance at the data

# %%
data = pd.read_csv("creditcard.csv")
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %% [markdown]
# We see the data is not in terms of features, these are PCA Components, sinc eit had to keep the data confidential

# %% [markdown]
# Class is our target variable
# where
# 0 = No Fruad
# 1 = Fruad

# %% [markdown]
# # EDA

# %%
data.isnull().values.any()
# Out:
# False

# %% [markdown]
# Meaning there are no missing values in the data

# %% [markdown]
# Lets check what the dirtibution is of the data with respect to Class
# which is our target variable

# %%
count_classes = pd.value_counts(data['Class'], sort = True)

count_classes.plot(kind = 'bar', rot = 0)

plt.title("Transaction Class Distribution")

plt.xticks(range(2), LABELS)

plt.xlabel("Class")

plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# From the above figure we see that the data is very imbalanced

# %% [markdown]
# getting fraud and normal data in different dataframe

# %%
normal = data[data['Class']==0]

fraud = data[data['Class']==1]

# %%
print("normal shape = ",normal.shape)

print("fraud shape = ",fraud.shape)
# Out:
# normal shape =  (284315, 31)
# fraud shape =  (492, 31)

# %% [markdown]
# Analyze the amount of transaction for both transaction and fraud

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
f, (ax1, ax2) = plt.subplots(2,1, sharex=True)
#here sharex is used to share the x axis between the plots
#and subplot is used when we want one or more plots in one figure

f.suptitle('Amount per transactions by class')
bins = 50
ax1.hist(fraud.Amount, bins = bins)
ax1.set_title('Fraud')

ax2.hist(normal.Amount, bins = bins)
ax2.set_title('Normal')

plt.xlabel('Amount($)')
plt.ylabel('Number of Transactions')
plt.xlim((0, 20000))
plt.yscale('log')
plt.show()

# %% [markdown]
# From the above two plots we see that the amount of Fraud is very less while for the normal transactions the amount is very high and is left skewed.

# %% [markdown]
# Lets check the scatter plot with respect to time and Amount
#
# Meaning do fraudulent transactions occur more often during certain time frame?

# %%
f, (ax1, ax2) = plt.subplots(2,1, sharex=True)
#here sharex is used to share the x axis between the plots
#and subplot is used when we want one or more plots in one figure

f.suptitle('Time of transaction vs Amount by class')

ax1.scatter(fraud.Time, fraud.Amount)
ax1.set_title('Fraud')

ax2.scatter(normal.Time, normal.Amount)
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()

# %% [markdown]
# Since the data is very large we will just take a small sample and then work on it for the model

# %%
data_sample = data.sample(frac = 0.1, random_state=1)

data_sample.shape
# Out:
# (28481, 31)

# %%
data.shape
# Out:
# (284807, 31)

# %% [markdown]
# From the above shape we see that we have taken exactly 1% of the total data in the sample

# %%
#Determining the fraud and normal transactions in the sample data

Fraud = data_sample[data_sample['Class']==1]

Normal = data_sample[data_sample['Class']==0]

outlier_fraction = len(Fraud)/float(len(Normal))

# %%
print(outlier_fraction)
print("Fraud Cases: ", len(Fraud))
print("Normal Cases: ",len(Normal))
# Out:
# 0.0017234102419808666
# Fraud Cases:  49
# Normal Cases:  28432

# %% [markdown]
# Lets check the correlation between the features

# %%
corrmat = data_sample.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))

g=sns.heatmap(data[top_corr_features].corr(), annot=True, cmap="YlGnBu", linewidth=0.3)

# %%
columns = data_sample.columns.tolist()

#Variables that we want to include as independent variables
columnsToInclude = [c for c in columns if c not in ["Class"]]
#Variable that we are predicting
target = "Class"
#Defining a random state
state = np.random.RandomState(RANDOM_SEED)
X = data_sample[columnsToInclude]
Y = data_sample[target]

X_outliers = state.uniform(low=0, high=1, size=(X.shape[0], X.shape[0]))

print(X.shape)
print(Y.shape)
# Out:
# (28481, 30)
# (28481,)

# %% [markdown]
# # Model Prediction

# %% [markdown]
# Isolation Forest Algorithm
#
# Local Outlier Factor Algorithm
#
# Support Vector Machine

# %%
#Creating a dictionary for all the classifiers
classifiers = {"Isolation Forest":IsolationForest(n_estimators=100, max_samples=len(X),
                                                  contamination=outlier_fraction,random_state=state, verbose=0),
    "Local Outlier Factor":LocalOutlierFactor(n_neighbors=20, algorithm='auto', 
                                              leaf_size=30, metric='minkowski',
                                              p=2, metric_params=None, contamination=outlier_fraction),
    "Support Vector Machine":OneClassSVM(kernel='rbf', degree=3, gamma=0.1,nu=0.05, 
                                         max_iter=-1, random_state=state)
   
}

# %%
type(classifiers)
# Out:
# dict

# %%
#running all the classifiers
n_outliers = len(Fraud)
for i, (clf_name, clf) in enumerate(classifiers.items()):
    #Fit the data and tag outliers
    if clf_name == "Local Outlier Factor":
        y_pred = clf.fit_predict(X)
        scores = clf.negative_outlier_factor_
    elif clf_name == "Support Vector Machine":
        clf.fit(X)
        y_pred = clf.predict(X)
    else:    
        clf.fit(X)
        scores_prediction = clf.decision_function(X)
        y_pred = clf.predict(X)
    #Reshape the prediction values to 0 for Valid transactions , 1 for Fraud transactions
    y_pred[y_pred == 1] = 0
    y_pred[y_pred == -1] = 1
    n_errors = (y_pred != Y).sum()
    # Run Classification Metrics
    print("{}: {}".format(clf_name,n_errors))
    print("Accuracy Score :")
    print(accuracy_score(Y,y_pred))
    print("Classification Report :")
    print(classification_report(Y,y_pred))
# Out:
# C:\Users\shahr\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# C:\Users\shahr\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:415: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# Isolation Forest: 73
# Accuracy Score :
# 0.9974368877497279
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28432
#            1       0.26      0.27      0.26        49
#
#     accuracy                           1.00     28481
#    macro avg       0.63      0.63      0.63     28481
# weighted avg       1.00      1.00      1.00     28481
#
# Local Outlier Factor: 97
# Accuracy Score :
# ...

# %% [markdown]
# # Observations :

# %% [markdown]
# Isolation Forest detected 73 errors versus Local Outlier Factor detecting 97 errors vs. SVM detecting 8516 errors
#
# Isolation Forest has a 99.74% more accurate than LOF of 99.65% and SVM of 70.09
#
# When comparing error precision & recall for 3 models , the Isolation Forest performed much better than the LOF as we can see that the detection of fraud cases is around 27 % versus LOF detection rate of just 2 % and SVM of 0%.
#
# So overall Isolation Forest Method performed much better in determining the fraud cases which is around 30%.
#
# We can also improve on this accuracy by increasing the sample size or use deep learning algorithms however at the cost of computational expense.We can also use complex anomaly detection models to get better accuracy in determining more fraudulent cases
